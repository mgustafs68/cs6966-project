# %%
import pandas as pd

clean = pd.read_csv("/uufs/chpc.utah.edu/common/home/u1528744/interpretability/cs6966-project/outputs/latent_partition/clean_pair_decoder_partitions.csv")

# %%
buggy = pd.read_csv("/uufs/chpc.utah.edu/common/home/u1528744/interpretability/cs6966-project/outputs/latent_partition/buggy_pair_decoder_partitions.csv")
